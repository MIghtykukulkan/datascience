# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('UNRATE.csv', header = None)
data.columns = ['Date','Rating']
data = data.set_index('Date')
data.head(12)
# Out:
#             Rating
# Date
# 01-01-1948     3.4
# 01-02-1948     3.8
# 01-03-1948     4.0
# 01-04-1948     3.9
# 01-05-1948     3.5
# 01-06-1948     3.6
# 01-07-1948     3.6
# 01-08-1948     3.9
# 01-09-1948     3.8
# 01-10-1948     3.7
# 01-11-1948     3.8
# 01-12-1948     4.0

# %%
data.plot(figsize=(12, 4))
plt.legend(loc='best')
plt.title('Rating')
plt.show(block=False)

# %%
from scipy.stats import boxcox
data_boxcox = pd.Series(boxcox(data['Rating'], lmbda=0), index = data.index)

plt.figure(figsize=(12,4))
plt.plot(data_boxcox, label='After Box Cox tranformation')
plt.legend(loc='best')
plt.title('After Box Cox transform')
plt.show()

# %%
data_boxcox_diff = pd.Series(data_boxcox - data_boxcox.shift(), data.index)
plt.figure(figsize=(12,4))
plt.plot(data_boxcox_diff, label='After Box Cox tranformation and differencing')
plt.legend(loc='best')
plt.title('After Box Cox transform and differencing')
plt.show()

# %%
data_boxcox_diff.dropna(inplace=True)

# %%
train_len = 612
train_data_boxcox = data_boxcox[:train_len]
test_data_boxcox = data_boxcox[train_len:]
train_data_boxcox_diff = data_boxcox_diff[:train_len-1]
test_data_boxcox_diff = data_boxcox_diff[train_len-1:]

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(train_data_boxcox_diff, order=(1, 0, 0)) 
model_fit = model.fit()
print(model_fit.params)
# Out:
# const         0.000131
# ar.L1.D2.y   -0.708137
# dtype: float64
# /home/umashankar/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /home/umashankar/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'

# %%
y_hat_ar = data_boxcox_diff.copy()
y_hat_ar['ar_forecast_boxcox_diff'] = model_fit.predict(data_boxcox_diff.index.min(), data_boxcox_diff.index.max())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '01-12-2019'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_index_label_loc(key, index, row_labels)
#     223             if not isinstance(key, (int, np.integer)):
# --> 224                 loc = row_labels.get_loc(key)
#     225             else:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#
# KeyError: '01-12-2019'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     330     try:
# --> 331         end, end_index, end_oos = get_index_label_loc(end, base_index, data.row_labels)
#     332     except KeyError:
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_index_label_loc(key, index, row_labels)
#     255         except:
# --> 256             raise e
#     257     return loc, index, index_was_expanded
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_index_label_loc(key, index, row_labels)
#     219     try:
# --> 220         loc, index, index_was_expanded = get_index_loc(key, index)
#     221     except KeyError as e:
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_index_loc(key, index)
#     169         except (IndexError, ValueError) as e:
# --> 170             raise KeyError(str(e))
#     171         loc = key
#
# KeyError: 'only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-109c5b7a63ee> in <module>
#       1 y_hat_ar = data_boxcox_diff.copy()
# ----> 2 y_hat_ar['ar_forecast_boxcox_diff'] = model_fit.predict(data_boxcox_diff.index.min(), data_boxcox_diff.index.max())
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/base/wrapper.py in wrapper(self, *args, **kwargs)
#     111             obj = data.wrap_output(func(results, *args, **kwargs), how[0], how[1:])
#     112         elif how:
# --> 113             obj = data.wrap_output(func(results, *args, **kwargs), how)
#     114         return obj
#     115
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in predict(self, start, end, exog, typ, dynamic)
#    1888     def predict(self, start=None, end=None, exog=None, typ='linear',
#    1889                 dynamic=False):
# -> 1890         return self.model.predict(self.params, start, end, exog, typ, dynamic)
#    1891
#    1892     def _forecast_error(self, steps):
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in predict(self, params, start, end, exog, typ, dynamic)
#    1256             if not dynamic or (start != self.k_ar + self.k_diff and
#    1257                                start is not None):
# -> 1258                 return super(ARIMA, self).predict(params, start, end, exog,
#    1259                                                   dynamic)
#    1260             else:
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in predict(self, params, start, end, exog, dynamic, **kwargs)
#     766         # will return an index of a date
#     767         start, end, out_of_sample, _ = (
# --> 768             self._get_prediction_index(start, end, dynamic))
#     769
#     770         if out_of_sample and (exog is None and self.k_exog > 0):
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in _get_prediction_index(self, start, end, dynamic, index)
#    1134
#    1135         start, end, out_of_sample, prediction_index = (
# -> 1136             super(ARIMA, self)._get_prediction_index(start, end, index))
#    1137
#    1138         # From _get_predict_end
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in _get_prediction_index(self, start, end, dynamic, index)
#     695
#     696         start, end, out_of_sample, prediction_index = (
# --> 697             super(ARMA, self)._get_prediction_index(start, end, index))
#     698
#     699         # This replaces the _validate() call
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in _get_prediction_index(self, start, end, index, silent)
#     736         """
#     737         nobs = len(self.endog)
# --> 738         return get_prediction_index(start,
#     739                                     end,
#     740                                     nobs,
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     331         end, end_index, end_oos = get_index_label_loc(end, base_index, data.row_labels)
#     332     except KeyError:
# --> 333         raise KeyError('The `end` argument could not be matched to a'
#     334                        ' location related to the index of the data.')
#     335
#
# KeyError: 'The `end` argument could not be matched to a location related to the index of the data.'

# %%
y_hat_ar = data_boxcox_diff.copy()
y_hat_ar['ar_forecast_boxcox_diff'] = model_fit.predict(data_boxcox_diff.index.min(), data_boxcox_diff.index.max())
y_hat_ar['ar_forecast_boxcox'] = y_hat_ar['ar_forecast_boxcox_diff'].cumsum()
y_hat_ar['ar_forecast_boxcox'] = y_hat_ar['ar_forecast_boxcox'].add(data_boxcox[0])
y_hat_ar['ar_forecast'] = np.exp(y_hat_ar['ar_forecast_boxcox'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '01-12-2019'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_index_label_loc(key, index, row_labels)
#     223             if not isinstance(key, (int, np.integer)):
# --> 224                 loc = row_labels.get_loc(key)
#     225             else:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#
# KeyError: '01-12-2019'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     330     try:
# --> 331         end, end_index, end_oos = get_index_label_loc(end, base_index, data.row_labels)
#     332     except KeyError:
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_index_label_loc(key, index, row_labels)
#     255         except:
# --> 256             raise e
#     257     return loc, index, index_was_expanded
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_index_label_loc(key, index, row_labels)
#     219     try:
# --> 220         loc, index, index_was_expanded = get_index_loc(key, index)
#     221     except KeyError as e:
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_index_loc(key, index)
#     169         except (IndexError, ValueError) as e:
# --> 170             raise KeyError(str(e))
#     171         loc = key
#
# KeyError: 'only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-a9c7e05b9f96> in <module>
#       1 y_hat_ar = data_boxcox_diff.copy()
# ----> 2 y_hat_ar['ar_forecast_boxcox_diff'] = model_fit.predict(data_boxcox_diff.index.min(), data_boxcox_diff.index.max())
#       3 y_hat_ar['ar_forecast_boxcox'] = y_hat_ar['ar_forecast_boxcox_diff'].cumsum()
#       4 y_hat_ar['ar_forecast_boxcox'] = y_hat_ar['ar_forecast_boxcox'].add(data_boxcox[0])
#       5 y_hat_ar['ar_forecast'] = np.exp(y_hat_ar['ar_forecast_boxcox'])
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/base/wrapper.py in wrapper(self, *args, **kwargs)
#     111             obj = data.wrap_output(func(results, *args, **kwargs), how[0], how[1:])
#     112         elif how:
# --> 113             obj = data.wrap_output(func(results, *args, **kwargs), how)
#     114         return obj
#     115
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in predict(self, start, end, exog, dynamic, **kwargs)
#    1562     def predict(self, start=None, end=None, exog=None, dynamic=False,
#    1563                 **kwargs):
# -> 1564         return self.model.predict(self.params, start, end, exog, dynamic,
#    1565                                   **kwargs)
#    1566
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in predict(self, params, start, end, exog, dynamic, **kwargs)
#     766         # will return an index of a date
#     767         start, end, out_of_sample, _ = (
# --> 768             self._get_prediction_index(start, end, dynamic))
#     769
#     770         if out_of_sample and (exog is None and self.k_exog > 0):
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py in _get_prediction_index(self, start, end, dynamic, index)
#     695
#     696         start, end, out_of_sample, prediction_index = (
# --> 697             super(ARMA, self)._get_prediction_index(start, end, index))
#     698
#     699         # This replaces the _validate() call
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in _get_prediction_index(self, start, end, index, silent)
#     736         """
#     737         nobs = len(self.endog)
# --> 738         return get_prediction_index(start,
#     739                                     end,
#     740                                     nobs,
#
# ~/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     331         end, end_index, end_oos = get_index_label_loc(end, base_index, data.row_labels)
#     332     except KeyError:
# --> 333         raise KeyError('The `end` argument could not be matched to a'
#     334                        ' location related to the index of the data.')
#     335
#
# KeyError: 'The `end` argument could not be matched to a location related to the index of the data.'
